# %%
import matplotlib.pyplot as plt
import numpy as np
import gzip
import pickle
import librosa

import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Bidirectional
from keras.layers import ConvLSTM2D
from keras.utils import np_utils

from keras.models import Model
from keras.layers import Dense, Input
from keras.datasets import mnist
from keras.regularizers import l1
from keras.optimizers import Adam

import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pickle_off=gzip.open("drive/My Drive/Colab Notebooks/Data/NSynth_onenote.data","rb")
emp=pickle.load(pickle_off)

# %%
sampling_rate=44100
nsamples=len(emp);
nmfccs=24;
nchroma=24;
ncontrast=6;
nbands=6;
ntrain=600;
nfeatures=131*(nmfccs)
n_y = len(emp[0][1])

X=np.zeros((nsamples,131,nmfccs+nchroma+6+ncontrast+1+1))
y=np.zeros((nsamples,n_y))
for i in range(nsamples):
    mfccTemp=librosa.feature.mfcc(y=np.array(emp[i][0]), sr=sampling_rate,n_mfcc=nmfccs)
    censTemp=librosa.feature.chroma_cens(y=np.array(emp[i][0]), sr=sampling_rate,n_chroma=nchroma)
    toneTemp=librosa.feature.tonnetz(y=np.array(emp[i][0]), sr=sampling_rate)
    spectralBandTemp=librosa.feature.spectral_bandwidth(y=np.array(emp[i][0]))
    spectralContrastTemp=librosa.feature.spectral_contrast(y=np.array(emp[i][0]),n_bands=nbands)
    spectralFlatnessTemp=librosa.feature.spectral_flatness(y=np.array(emp[i][0]))
    spectralRollTemp=librosa.feature.spectral_rolloff(y=np.array(emp[i][0]))
    feature=np.concatenate((mfccTemp,censTemp))
    feature=np.concatenate((feature,toneTemp))
    feature=np.concatenate((feature,spectralBandTemp))
    feature=np.concatenate((feature,spectralContrastTemp))
    X[i,:]=np.transpose(feature)
    y[i,:]=([emp[i][1][j][1] for j in range(0,n_y)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-e9d1c19553e8> in <module>()
#      14     mfccTemp=librosa.feature.mfcc(y=np.array(emp[i][0]), sr=sampling_rate,n_mfcc=nmfccs)
#      15     censTemp=librosa.feature.chroma_cens(y=np.array(emp[i][0]), sr=sampling_rate,n_chroma=nchroma)
# ---> 16     toneTemp=librosa.feature.tonnetz(y=np.array(emp[i][0]), sr=sampling_rate)
#      17     spectralBandTemp=librosa.feature.spectral_bandwidth(y=np.array(emp[i][0]))
#      18     spectralContrastTemp=librosa.feature.spectral_contrast(y=np.array(emp[i][0]),n_bands=nbands)
#
# /usr/local/lib/python3.6/dist-packages/librosa/feature/spectral.py in tonnetz(y, sr, chroma)
#    1321
#    1322     if chroma is None:
# -> 1323         chroma = chroma_cqt(y=y, sr=sr)
#    1324
#    1325     # Generate Transformation matrix
#
# /usr/local/lib/python3.6/dist-packages/librosa/feature/spectral.py in chroma_cqt(y, sr, C, hop_length, fmin, norm, threshold, tuning, n_chroma, n_octaves, window, bins_per_octave, cqt_mode)
#    1077                                       n_bins=n_octaves * bins_per_octave,
#    1078                                       bins_per_octave=bins_per_octave,
# -> 1079                                       tuning=tuning))
#    1080
#    1081     # Map to chroma
#
# /usr/local/lib/python3.6/dist-packages/librosa/core/constantq.py in cqt(y, sr, hop_length, fmin, n_bins, bins_per_octave, tuning, filter_scale, norm, sparsity, window, scale, pad_mode)
#     183                                            res_type,
#     184                                            n_octaves,
# --> 185                                            nyquist, filter_cutoff, scale)
#     186
#     187     cqt_resp = []
#
# /usr/local/lib/python3.6/dist-packages/librosa/core/constantq.py in __early_downsample(y, sr, hop_length, res_type, n_octaves, nyquist, filter_cutoff, scale)
#     818         y = audio.resample(y, sr, new_sr,
#     819                            res_type=res_type,
# --> 820                            scale=True)
#     821
#     822         # If we're not going to length-scale after CQT, we
#
# /usr/local/lib/python3.6/dist-packages/librosa/core/audio.py in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     291         y_hat = scipy.signal.resample(y, n_samples, axis=-1)
#     292     else:
# --> 293         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     294
#     295     if fix:
#
# /usr/local/lib/python3.6/dist-packages/resampy/core.py in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#     111     x_2d = x.swapaxes(0, axis).reshape((x.shape[axis], -1))
#     112     y_2d = y.swapaxes(0, axis).reshape((y.shape[axis], -1))
# --> 113     resample_f(x_2d, y_2d, sample_ratio, interp_win, interp_delta, precision)
#     114
#     115     return y
#
# KeyboardInterrupt:

# %%
numpy.random.seed(seed=5)
trainIndex=set(np.random.choice(nsamples,size=ntrain,replace=False))
testIndex=set(np.linspace(0,nsamples-1,nsamples))-trainIndex

# %%
x_train=X[np.array(list(trainIndex),dtype=int),:]
y_train=y[np.array(list(trainIndex),dtype=int),:]
x_test=X[np.array(list(testIndex),dtype=int),:]
y_test=y[np.array(list(testIndex),dtype=int),:]

# %%
def diffSizes(data, divide_by):
  ncol = data.shape[1]
  input_size = ncol
  hidden_size = ncol - ((ncol//divide_by)//2)
  code_size = ncol//divide_by
  return input_size, hidden_size, code_size

def runAEC(x_train,x_test,x_full):
  input_size, hidden_size, code_size = diffSizes(x_train, 2)
  input_img = Input(shape=(input_size,))
  hidden_1 = Dense(hidden_size, activation='relu')(input_img)
  code = Dense(code_size, activation='relu')(hidden_1)
  hidden_2 = Dense(hidden_size, activation='relu')(code)
  output_img = Dense(input_size, activation='sigmoid')(hidden_2)
  autoencoder = Model(input_img, output_img)
  autoencoder.compile(optimizer='rmsprop', loss='mse')
  autoencoder.fit(x_train, x_train, epochs=10)
  score = autoencoder.evaluate(x_test, x_test, batch_size=100)
  print(np.sqrt(score))
  #autoencoder.summary()
  encoder = Model(inputs = input_img, outputs = code)
  encoded_input = Input(shape = (code_size, ))
  encoded_train = pd.DataFrame(encoder.predict(x_full))
  encoded_train = encoded_train.add_prefix('feature_')
  return encoded_train

# %%
synth1_encoded = runAEC(y_train,y_test,y)
y_ae0 = np.array(synth1_encoded)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 1s 1ms/step - loss: 0.0836
# Epoch 2/10
# 600/600 [==============================] - 0s 157us/step - loss: 0.0828
# Epoch 3/10
# 600/600 [==============================] - 0s 148us/step - loss: 0.0817
# Epoch 4/10
# 600/600 [==============================] - 0s 150us/step - loss: 0.0803
# Epoch 5/10
# 600/600 [==============================] - 0s 155us/step - loss: 0.0787
# Epoch 6/10
# 600/600 [==============================] - 0s 146us/step - loss: 0.0774
# Epoch 7/10
# 600/600 [==============================] - 0s 151us/step - loss: 0.0761
# Epoch 8/10
# 600/600 [==============================] - 0s 147us/step - loss: 0.0746
# Epoch 9/10
# 600/600 [==============================] - 0s 148us/step - loss: 0.0734
# Epoch 10/10
# 600/600 [==============================] - 0s 143us/step - loss: 0.0722
# 400/400 [==============================] - 0s 520us/step
# 0.2779356825149143

# %%
y_train_reduced=y_ae0[np.array(list(trainIndex),dtype=int),:]
y_test_reduced=y_ae0[np.array(list(testIndex),dtype=int),:]

# %%
model=Sequential()
model.add(LSTM(24, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dense(y_train_reduced.shape[1], activation='relu'))
model.compile(optimizer='Nadam',
              loss='mse')
model.fit(x_train, y_train_reduced,
          epochs=40,
          batch_size=10)
score = model.evaluate(x_test, y_test_reduced, batch_size=100)
model.save('drive/My Drive/Comp562LSTM24Nadam24.h5')
print(np.sqrt(score))
#0.2948985627415366
# Out:
# Epoch 1/40
# 600/600 [==============================] - 5s 8ms/step - loss: 0.2225
# Epoch 2/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1193
# Epoch 3/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1129
# Epoch 4/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1114
# Epoch 5/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1107
# Epoch 6/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1106
# Epoch 7/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1102
# Epoch 8/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1098
# Epoch 9/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1095
# Epoch 10/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1094
# Epoch 11/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1093
# Epoch 12/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1092
# Epoch 13/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1091
# Epoch 14/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1088
# Epoch 15/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1087
# Epoch 16/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1087
# Epoch 17/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1090
# Epoch 18/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1088
# Epoch 19/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1087
# Epoch 20/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1086
# Epoch 21/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1086
# Epoch 22/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1085
# Epoch 23/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1085
# Epoch 24/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1105
# Epoch 25/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1098
# Epoch 26/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1052
# Epoch 27/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1049
# Epoch 28/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1048
# Epoch 29/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1042
# Epoch 30/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1042
# Epoch 31/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1043
# Epoch 32/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1041
# Epoch 33/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1039
# Epoch 34/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1048
# Epoch 35/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1041
# Epoch 36/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1042
# Epoch 37/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1041
# Epoch 38/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1042
# Epoch 39/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1040
# Epoch 40/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1040
# 400/400 [==============================] - 0s 1ms/step
# 0.30048581885716497

# %%
pred_y_0 = model.predict(x_test)

# %%
def decode(df,orig_test):
    input_size, hidden_size, code_size = diffSizes(orig_test, 2)
    input_img = Input(shape=(input_size,))
    hidden_1 = Dense(hidden_size, activation='relu')(input_img)
    encoded_input = Input(shape = (code_size, ))
    #code = Dense(code_size, activation='relu')(hidden_1)
    hidden_2 = Dense(hidden_size, activation='relu')(encoded_input)
    output_img = Dense(input_size, activation='sigmoid')(hidden_2)
    encoder = Model(inputs = encoded_input, outputs = output_img)
    decoded_test = encoder.predict(df)
    decoded_y_0 = np.array(pd.DataFrame(decoded_test))
    rmse = np.sqrt(np.mean((decoded_y_0 - orig_test)**2))
    return rmse

# %%
decode(pred_y_0, y_test)
# Out:
# 0.30119109302542313

# %%
model=Sequential()
model.add(LSTM(24, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dense(255, activation='relu'))
model.compile(optimizer='RMSprop',
              loss='mse')
model.fit(x_train, y_train,
          epochs=40,
          batch_size=10)
score = model.evaluate(x_test, y_test, batch_size=100)
model.save('drive/My Drive/Comp562LSTM24RMSprop24.h5')
print(np.sqrt(score))
#0.3024906623350846
# Out:
# Epoch 1/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.1823
# Epoch 2/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1213
# Epoch 3/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1071
# Epoch 4/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1019
# Epoch 5/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0992
# Epoch 6/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0983
# Epoch 7/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0976
# Epoch 8/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0972
# Epoch 9/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0962
# Epoch 10/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0950
# Epoch 11/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0944
# Epoch 12/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0936
# Epoch 13/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0930
# Epoch 14/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0929
# Epoch 15/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0925
# Epoch 16/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0920
# Epoch 17/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0918
# Epoch 18/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0916
# Epoch 19/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0917
# Epoch 20/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0916
# Epoch 21/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0915
# Epoch 22/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0914
# Epoch 23/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0914
# Epoch 24/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0913
# Epoch 25/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0913
# Epoch 26/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0906
# Epoch 27/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0902
# Epoch 28/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0902
# Epoch 29/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0901
# Epoch 30/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0901
# Epoch 31/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0901
# Epoch 32/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0900
# Epoch 33/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0900
# Epoch 34/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0901
# Epoch 35/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0900
# Epoch 36/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0900
# Epoch 37/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0899
# Epoch 38/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0899
# Epoch 39/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0899
# Epoch 40/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0899
# 400/400 [==============================] - 1s 3ms/step
# 0.3024906623350846

# %%
model=Sequential()
model.add(LSTM(24, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dense(255, activation='relu'))
model.compile(optimizer='sgd',
              loss='mse')
model.fit(x_train, y_train,
          epochs=40,
          batch_size=10)
score = model.evaluate(x_test, y_test, batch_size=100)
model.save('drive/My Drive/Comp562LSTM24sgd24.h5')
print(np.sqrt(score))
#0.42599756100761205
# Out:
# Epoch 1/40
# 600/600 [==============================] - 6s 11ms/step - loss: 0.2668
# Epoch 2/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2618
# Epoch 3/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2590
# Epoch 4/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2557
# Epoch 5/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2525
# Epoch 6/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2495
# Epoch 7/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2468
# Epoch 8/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2438
# Epoch 9/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2412
# Epoch 10/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2385
# Epoch 11/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2357
# Epoch 12/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2330
# Epoch 13/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2305
# Epoch 14/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2281
# Epoch 15/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2258
# Epoch 16/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2238
# Epoch 17/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2217
# Epoch 18/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2197
# Epoch 19/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2177
# Epoch 20/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2152
# Epoch 21/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2116
# Epoch 22/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2096
# Epoch 23/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2077
# Epoch 24/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2059
# Epoch 25/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2040
# Epoch 26/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2021
# Epoch 27/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.2002
# Epoch 28/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1983
# Epoch 29/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1962
# Epoch 30/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1944
# Epoch 31/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1926
# Epoch 32/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1911
# Epoch 33/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1895
# Epoch 34/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1881
# Epoch 35/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1867
# Epoch 36/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1854
# Epoch 37/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1842
# Epoch 38/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1829
# Epoch 39/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1817
# Epoch 40/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.1806
# 400/400 [==============================] - 1s 3ms/step
# 0.42599756100761205

# %%
model=Sequential()
model.add(LSTM(24, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dense(255, activation='relu'))
model.compile(optimizer='adagrad',
              loss='mse')
model.fit(x_train, y_train,
          epochs=40,
          batch_size=10)
score = model.evaluate(x_test, y_test, batch_size=100)
model.save('drive/My Drive/Comp562LSTM24Adagrad24.h5')
print(np.sqrt(score))
#0.30804447894382314
# Out:
# Epoch 1/40
# 600/600 [==============================] - 7s 11ms/step - loss: 0.1345
# Epoch 2/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1055
# Epoch 3/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1022
# Epoch 4/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0997
# Epoch 5/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0971
# Epoch 6/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0966
# Epoch 7/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0963
# Epoch 8/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0961
# Epoch 9/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0964
# Epoch 10/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0970
# Epoch 11/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0967
# Epoch 12/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0945
# Epoch 13/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0944
# Epoch 14/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0943
# Epoch 15/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0942
# Epoch 16/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0941
# Epoch 17/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0941
# Epoch 18/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0940
# Epoch 19/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0939
# Epoch 20/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0939
# Epoch 21/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0938
# Epoch 22/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0937
# Epoch 23/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0937
# Epoch 24/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0937
# Epoch 25/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0936
# Epoch 26/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0936
# Epoch 27/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0935
# Epoch 28/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0935
# Epoch 29/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0935
# Epoch 30/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0934
# Epoch 31/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0934
# Epoch 32/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0934
# Epoch 33/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0933
# Epoch 34/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0933
# Epoch 35/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0933
# Epoch 36/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0933
# Epoch 37/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0932
# Epoch 38/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0932
# Epoch 39/40
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0932
# Epoch 40/40
# 600/600 [==============================] - 4s 6ms/step - loss: 0.0932
# 400/400 [==============================] - 1s 3ms/step
# 0.30804447894382314

# %%
model2=Sequential()
model2.add(Bidirectional(LSTM(24, input_shape=(x_train.shape[1], x_train.shape[2]))))
model2.add(Dense(255, activation='relu'))
model2.compile(optimizer='Nadam',
              loss='mse')
model2.fit(x_train, y_train,
          epochs=40,
          batch_size=10)
score = model2.evaluate(x_test, y_test, batch_size=100)
model2.save('drive/My Drive/Comp562/BiLSTM24Nadam24.h5')
print(np.sqrt(score))
#0.3131173651729559
# Out:
# Epoch 1/40
# 600/600 [==============================] - 9s 16ms/step - loss: 0.1444
# Epoch 2/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.1025
# Epoch 3/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0999
# Epoch 4/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0990
# Epoch 5/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0985
# Epoch 6/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0978
# Epoch 7/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0970
# Epoch 8/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0966
# Epoch 9/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0964
# Epoch 10/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0962
# Epoch 11/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0960
# Epoch 12/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0960
# Epoch 13/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0959
# Epoch 14/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0958
# Epoch 15/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0957
# Epoch 16/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0956
# Epoch 17/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0955
# Epoch 18/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0954
# Epoch 19/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0953
# Epoch 20/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0953
# Epoch 21/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0952
# Epoch 22/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0951
# Epoch 23/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0951
# Epoch 24/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0950
# Epoch 25/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0950
# Epoch 26/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0949
# Epoch 27/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0948
# Epoch 28/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0948
# Epoch 29/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0945
# Epoch 30/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0940
# Epoch 31/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0939
# Epoch 32/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0940
# Epoch 33/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0940
# Epoch 34/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0940
# Epoch 35/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0940
# Epoch 36/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0939
# Epoch 37/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0939
# Epoch 38/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0937
# Epoch 39/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0937
# Epoch 40/40
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0937
# 400/400 [==============================] - 1s 4ms/step
# 0.3131173651729559

# %%
model1=Sequential()
model1.add(GRU(24, input_shape=(x_train.shape[1], x_train.shape[2])))
model1.add(Dense(255, activation='relu'))
model1.compile(optimizer='Nadam',
              loss='mse')
model1.fit(x_train, y_train,
          epochs=40,
          batch_size=10)
score = model1.evaluate(x_test, y_test, batch_size=100)
model1.save('drive/My Drive/Comp562/GRU24Nadam24.h5')
print(np.sqrt(score))
#0.30473644218082063
# Out:
# Epoch 1/40
# 600/600 [==============================] - 6s 11ms/step - loss: 0.1525
# Epoch 2/40
# 600/600 [==============================] - 3s 6ms/step - loss: 0.1019
# Epoch 3/40
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0957
# Epoch 4/40
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0930
# Epoch 5/40
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0924
# Epoch 6/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0919
# Epoch 7/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0915
# Epoch 8/40
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0913
# Epoch 9/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0912
# Epoch 10/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0910
# Epoch 11/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0910
# Epoch 12/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0907
# Epoch 13/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0908
# Epoch 14/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0906
# Epoch 15/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0905
# Epoch 16/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0905
# Epoch 17/40
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0905
# Epoch 18/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0905
# Epoch 19/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0905
# Epoch 20/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0904
# Epoch 21/40
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0903
# Epoch 22/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0903
# Epoch 23/40
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0902
# Epoch 24/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0903
# Epoch 25/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0902
# Epoch 26/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0903
# Epoch 27/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0902
# Epoch 28/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0902
# Epoch 29/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0901
# Epoch 30/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0901
# Epoch 31/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0902
# Epoch 32/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0902
# Epoch 33/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0901
# Epoch 34/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0901
# Epoch 35/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0900
# Epoch 36/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0901
# Epoch 37/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0901
# Epoch 38/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0902
# Epoch 39/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0902
# Epoch 40/40
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0901
# 400/400 [==============================] - 1s 3ms/step
# 0.30473644218082063
